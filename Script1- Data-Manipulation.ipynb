# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + "//Data - Survey Monkey Edited.xlsx",sheet_name="Edited_data")

# %%
dataset.head()
# Out:
#    Respondent ID -        Start Date -          End Date -   Email Address -   \
# 0      5.379192e+09 2021-01-22 12:01:17 2021-01-22 12:40:34               NaN
# 1      2.658723e+09 2021-01-22 06:56:37 2021-01-22 07:34:10               NaN
# 2      4.044163e+09 2021-01-22 06:35:18 2021-01-22 06:47:32               NaN
# 3      5.535866e+09 2021-01-21 21:29:32 2021-01-21 21:40:24               NaN
# 4      3.356803e+09 2021-01-21 17:26:39 2021-01-21 17:44:40               NaN
#
#    First Name -   Last Name -   Custom Data 1 -   \
# 0            NaN           NaN               NaN
# 1            NaN           NaN               NaN
# 2            NaN           NaN               NaN
# 3            NaN           NaN               NaN
# 4            NaN           NaN               NaN
#
#   Identify which division you work in. - Response  \
# 0                                  Infrastructure
# 1                                         Finance
# ...

# %%
data_modified = dataset.copy()

# %%
data_modified.columns
# Out:
# Index(['Respondent ID - ', 'Start Date - ', 'End Date - ', 'Email Address - ',
#        'First Name - ', 'Last Name - ', 'Custom Data 1 - ',
#        'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question 1 - Response', 'Question 2 - Response',
#        'Question 3 - Open-Ended Response', 'Question 4 - Response',
#        'Question 4 - Other (please specify)', 'Question 5 - Response 1',
#        'Question 5 - Response 2', 'Question 5 - Response 3',
#        'Question 5 - Response 4', 'Question 5 - Response 5',
# ...

# %%
Colunms_to_drop = ['Start Date - ', 'End Date - ', 'Email Address - ',
       'First Name - ', 'Last Name - ', 'Custom Data 1 - ']

# %%
data_modified.drop(columns=Colunms_to_drop,inplace=True)

# %%
data_modified
# Out:
#      Respondent ID -  Identify which division you work in. - Response  \
# 0        5.379192e+09                                  Infrastructure
# 1        2.658723e+09                                         Finance
# 2        4.044163e+09                                  Infrastructure
# 3        5.535866e+09                                  Infrastructure
# 4        3.356803e+09                                 Port Operations
# ..                ...                                             ...
# 193      7.940065e+09                                  Infrastructure
# 194      5.157706e+09                                         Finance
# 195      9.920756e+09                                 Port Operations
# 196      6.638341e+09                                  Infrastructure
# 197      8.114622e+09                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# ...

# %% [markdown]
# #### UNPIVOT

# %%
id_vars = list(data_modified.columns)[:8]
value_vars = list(data_modified.columns)[8:]
dataset_melted = data_modified.melt(id_vars=id_vars, value_vars=value_vars,var_name="Question + Subquestion",value_name="Answer")

# %%
dataset_melted
# Out:
#        Respondent ID -  Identify which division you work in. - Response  \
# 0          5.379192e+09                                  Infrastructure
# 1          2.658723e+09                                         Finance
# 2          4.044163e+09                                  Infrastructure
# 3          5.535866e+09                                  Infrastructure
# 4          3.356803e+09                                 Port Operations
# ...                 ...                                             ...
# 17023      7.940065e+09                                  Infrastructure
# 17024      5.157706e+09                                         Finance
# 17025      9.920756e+09                                 Port Operations
# 17026      6.638341e+09                                  Infrastructure
# 17027      8.114622e+09                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
question_import = pd.read_excel(pwd + "//Data - Survey Monkey Edited.xlsx",sheet_name= "Question")

# %%
question_import
# Out:
#      Raw Question Raw sub-questions       Question     Question + Subquestion
# 0   Respondent ID               NaN  Respondent ID           Respondent ID -
# 1      Start Date               NaN     Start Date              Start Date -
# 2        End Date               NaN       End Date                End Date -
# 3   Email Address               NaN  Email Address           Email Address -
# 4      First Name               NaN     First Name              First Name -
# ..            ...               ...            ...                        ...
# 95            NaN       Response 13    Question 29  Question 29 - Response 13
# 96            NaN       Response 14    Question 29  Question 29 - Response 14
# 97    Question 30        Response 1    Question 30   Question 30 - Response 1
# 98            NaN        Response 2    Question 30   Question 30 - Response 2
# 99            NaN        Response 3    Question 30   Question 30 - Response 3
#
# [100 rows x 4 columns]

# %%
question_import.drop(columns=["Raw Question","Raw sub-questions"],inplace=True)

# %%
question_import.dropna(inplace=True)

# %%
question=question_import.copy

# %%
question
# Out:
# <bound method NDFrame.copy of          Question     Question + Subquestion
# 0   Respondent ID           Respondent ID -
# 1      Start Date              Start Date -
# 2        End Date                End Date -
# 3   Email Address           Email Address -
# 4      First Name              First Name -
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]>

# %% [markdown]
# #### Join the two imported file

# %%
dataset_merged =pd.merge(left=dataset_melted,right=question_import,how="left",left_on="Question + Subquestion",right_on="Question + Subquestion")

# %%
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 17028
# Merged Data 17028
#        Respondent ID -  Identify which division you work in. - Response  \
# 0          5.379192e+09                                  Infrastructure
# 1          2.658723e+09                                         Finance
# 2          4.044163e+09                                  Infrastructure
# 3          5.535866e+09                                  Infrastructure
# 4          3.356803e+09                                 Port Operations
# ...                 ...                                             ...
# 17023      7.940065e+09                                  Infrastructure
# 17024      5.157706e+09                                         Finance
# 17025      9.920756e+09                                 Port Operations
# 17026      6.638341e+09                                  Infrastructure
# 17027      8.114622e+09                          Information Technology
#
# ...

# %%
respondents = dataset_merged[dataset_merged['Answer'].notna()]

# %%
# pd.DataFrame(respondent)

# %%
respondents.columns
# Out:
# Index(['Respondent ID - ', 'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question + Subquestion', 'Answer', 'Question'],
#       dtype='object')

# %%
respondents.rename
# Out:
#        Respondent ID -  Identify which division you work in. - Response  \
# 1          2.658723e+09                                         Finance
# 2          4.044163e+09                                  Infrastructure
# 3          5.535866e+09                                  Infrastructure
# 5          3.399512e+09                                  Infrastructure
# 6          9.860597e+09                                  Infrastructure
# ...                 ...                                             ...
# 17017      9.735550e+09                                          People
# 17020      7.325852e+09                                  Infrastructure
# 17021      3.370366e+09            Port Security & Emergency Operations
# 17023      7.940065e+09                                  Infrastructure
# 17024      5.157706e+09                                         Finance
#
#       Identify which division you work in. - Other (please specify)  \
# ...
